# %%
import numpy as np
import matplotlib.pyplot as plt
from physics import compute_flux, GasState

# %%
rhoL, uL, pL = 1.0, 0.0, 1.0
rhoR, uR, pR = 1.0001, -1e-4, 1.001

gs = GasState.from_linear(rhoL=rhoL, uL=uL, pL=pL, rhoR=rhoR, uR=uR, pR=pR)

# %%
flux = compute_flux(1.0, gs)
print(flux)
# Out:
# [-4.37115209e-04  1.00056472e+00 -1.09358112e-03]
